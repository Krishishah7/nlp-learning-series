# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishishah7/nlp-learning-series/blob/main/01_embeddings/sentence_transformer_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence-transformers scikit-learn

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
sentences = [
    "Machine learning is transforming technology",
    "Artificial intelligence is changing the world",
    "I enjoy cooking and baking",
    "Natural language processing is part of AI",
    "Deep learning improves prediction accuracy"
]

# %%
embeddings = model.encode(sentences)

print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (5, 384)

# %%
sim_matrix = cosine_similarity(embeddings)

sim_matrix
# Out:
# array([[0.9999999 , 0.62962276, 0.08334295, 0.37203276, 0.4096532 ],
#        [0.62962276, 1.        , 0.09587133, 0.46549672, 0.36823344],
#        [0.08334295, 0.09587133, 1.        , 0.08459767, 0.05809576],
#        [0.37203276, 0.46549672, 0.08459767, 1.        , 0.2486046 ],
#        [0.4096532 , 0.36823344, 0.05809576, 0.2486046 , 1.0000002 ]],
#       dtype=float32)

# %%
query = "AI and machine learning"

query_vec = model.encode([query])

scores = cosine_similarity(query_vec, embeddings)[0]

for sent, score in sorted(zip(sentences, scores), key=lambda x: -x[1]):
    print(f"{sent} → {score:.3f}")
# Out:
# Machine learning is transforming technology → 0.613
# Artificial intelligence is changing the world → 0.567
# Natural language processing is part of AI → 0.534
# Deep learning improves prediction accuracy → 0.391
# I enjoy cooking and baking → 0.119

# %% [markdown]
# - Sentence transformers generate contextual embeddings for full sentences.
# - Similarity is computed using cosine similarity between embedding vectors.
# - Higher score = closer semantic meaning.
